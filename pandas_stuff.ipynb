# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.choice([2,np.nan], (20, 5), p=[0.2, 0.8]), columns=list('abcde'))

# %%
print(df)
# Out:
#       a    b    c    d    e
# 0   2.0  NaN  NaN  NaN  NaN
# 1   NaN  NaN  NaN  NaN  2.0
# 2   2.0  NaN  NaN  NaN  NaN
# 3   NaN  NaN  NaN  NaN  NaN
# 4   NaN  2.0  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN  NaN
# 7   NaN  2.0  NaN  2.0  NaN
# 8   NaN  NaN  2.0  NaN  NaN
# 9   NaN  NaN  NaN  NaN  NaN
# 10  NaN  NaN  NaN  2.0  NaN
# 11  NaN  NaN  NaN  NaN  NaN
# 12  2.0  NaN  2.0  NaN  NaN
# 13  NaN  NaN  NaN  NaN  NaN
# 14  2.0  NaN  NaN  2.0  NaN
# 15  NaN  NaN  NaN  NaN  NaN
# 16  NaN  NaN  NaN  2.0  NaN
# 17  NaN  NaN  NaN  NaN  NaN
# 18  NaN  NaN  2.0  NaN  2.0
# 19  NaN  NaN  NaN  NaN  NaN
